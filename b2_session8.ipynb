# %% [markdown]
# <a href="https://colab.research.google.com/github/tdiya99-creator/GLA-Bootcamp/blob/main/b2_session8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# +ve bag and a -ve bag

# %%
#The movie was good
#The movie was not good
#basic sequence

# %%
#architecture of higher defined sequencing
#RNN --LSTM--Transformers

# %%
#Hidden state means the models current summary of what it has read so far!

#The movie was not good

# Token 1:The
#memory: sentences has started

#Token 2:Movie
#memory: subject is movie

# Token 3:was
#memory: waiting for description

#Token 4:Not
#memory:negative active

#Token 5 : Good
#memory : good appear but not changing meaning

#FINAL SENTIMENT : NEGATION - NEGATIVE

# %%
sentence = "the movie was not good"
tokens = sentence.split()

memory = ""

for token in tokens:
  memory = memory + " "+ token
  print("Current token:",token)
  print("Memory so far:",memory.strip())
  print("-----")
# Out:
# Current token: the
# Memory so far: the
# -----
# Current token: movie
# Memory so far: the movie
# -----
# Current token: was
# Memory so far: the movie was
# -----
# Current token: not
# Memory so far: the movie was not
# -----
# Current token: good
# Memory so far: the movie was not good
# -----

# %%
sentence ="the movie was not good"
tokens = sentence.split()

hidden_state ={
    "topic":None,
    "negative_active":False,
    "sentiment_word":None
}
for toeken in tokens:
  if token in ["movie","food","product"]:
    hidden_state["topic"] = token

  if token=="not":
    hidden_state["negative_active"]=True

  if token in ["good","bad","great","terrible"]:
    hidden_state["sentiment_word"] = token


    print("Token:",token)
    print("Hidden state:", hidden_state)
    print("------")
# Out:
# Token: good
# Hidden state: {'topic': None, 'negative_active': False, 'sentiment_word': 'good'}
# ------
# Token: good
# Hidden state: {'topic': None, 'negative_active': False, 'sentiment_word': 'good'}
# ------
# Token: good
# Hidden state: {'topic': None, 'negative_active': False, 'sentiment_word': 'good'}
# ------
# Token: good
# Hidden state: {'topic': None, 'negative_active': False, 'sentiment_word': 'good'}
# ------
# Token: good
# Hidden state: {'topic': None, 'negative_active': False, 'sentiment_word': 'good'}
# ------

# %%
import tensorflow as tf
from tensorflow.keras import layers

vocab_size = 1000
embedding_dim = 16
sequence_length = 8

simple_rnn_model = tf.keras.Sequential([
    layers.Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=sequence_length),
    layers.SimpleRNN(units=32),
    layers.Dense(1, activation='sigmoid') #output is between 0 and 1, close to one mtlb intent positive, output is close to 0 intent will be negative
])
simple_rnn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#RNNs cannot works with long term memory
#long dependency is a must

@ as sequence length increases simple rnn memory becomes weak

#LSTM is an upgraded RNN


#LSTM= RNN+gates + cell states

#Cell state
LONG TERM MEMORY PATH

#HIDDEN STATE
current working memory

#forget gate - decides which old info to keep and which to drop

#Shivani watched the movie. The food was not good.

#Input Gate
Point to input gate

#The movie was not good

#output gate

#LSTM

# forget gate- cross out old info which is no longer required
#input gate decide what new information deserves a note
#candidate memory: the new note (important that could be written)
#cell state is the notebook
# Out:
#   File "/tmp/ipykernel_946/2267384665.py", line 4
#     @ as sequence length increases simple rnn memory becomes weak
#       ^
# SyntaxError: invalid syntax

# %%
#Sentence
#The movie was not good

#token: the
#cell state: sentence started

#token: movie
#cell state: subject is movie

#token: not
#input gate adds negation
#cell state: negation is active

#token good
#output gate exposes: not+good

#prediction becomes negative
